# %%
import random

students = [
    "Jaydeep",
    "Bhumi",
    "Shantanu",
    "Saish",
    "Sayali",
]

winner = random.sample(students, 3)

print("1st Prize: ",winner[0])
print("2nd Prize: ",winner[1])
print("3rd Prize: ",winner[2])
